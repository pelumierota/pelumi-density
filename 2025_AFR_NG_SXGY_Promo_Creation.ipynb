# %% [markdown]
# <a href="https://colab.research.google.com/github/pelumierota/pelumi-density/blob/main/2025_AFR_NG_SXGY_Promo_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/My\ Drive/Python/setup-454812-0882322d526c.json
# Out:
# '/content/drive/My Drive/Python/setup-454812-0882322d526c.json'

# %%
import os
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from gspread_dataframe import get_as_dataframe
import pandas as pd

# Configuración de las credenciales de Google
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/drive/My Drive/Python/setup-454812-0882322d526c.json"

# Obtener la ruta desde la variable de entorno
json_path = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")


# Verificar si la variable está definida
if not json_path:
    raise ValueError("No se encontró la variable de entorno GOOGLE_APPLICATION_CREDENTIALS.")

# Configurar la conexión con Google Sheets
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_path, scope)
client = gspread.authorize(credentials)

# %%
# Open the Google Sheets file by its title
file_title = 'NG CR 50 SXGY Promo'
spreadsheet = client.open(file_title)

# Access the sheet named "data1"
ws = spreadsheet.worksheet('Final')
existing = get_as_dataframe(ws,usecols=[20])
existing = existing.dropna(how='all')

# %%
existing.head(200)
# Out:
#                                             output.1
# 0  ['BASKET_PERCENTAGE','ABV','50% basket co-mtkg...
# 1  ,['BASKET_PERCENTAGE','GWA','50% basket co-mtk...
# 2  ,['BASKET_PERCENTAGE','KUB','50% basket co-mtk...
# 3  ,['BASKET_PERCENTAGE','LUE','50% basket co-mtk...
# 4  ,['BASKET_PERCENTAGE','PHC','50% basket co-mtk...

# %%
concatenated_output = "".join(existing['output.1'].tolist())

# Print the concatenated output
print(concatenated_output)
# Out:
# ['BASKET_PERCENTAGE','ABV','50% basket co-mtkg NG Chicken Republic 329678',1743670800000,1751274000000,False,'GLOVO_NEW_CUSTOMER',[
#     [
#       "id", 329678,
#       "paymentStrategy", "ASSUMED_BY_GLOVO",
#       "addresses", [592931,707325,490768,527426,527364,707303,681925,576286,707319,608169,537917,707290],
#       "commissionOnDiscountedPrice", False,
#       "subsidyStrategy", "BY_PERCENTAGE",
#       "sponsors", [
#         [
#           "sponsorId", 1,
#           "sponsorName", "Glovo",
#           "sponsorOrigin", "GLOVO",
#           "subsidyValue", 100
#         ]
#       ]
#     ]
#   ],50,None,0,None,350000],['BASKET_PERCENTAGE','GWA','50% basket co-mtkg NG Chicken Republic 377488',1743670800000,1751274000000,False,'GLOVO_NEW_CUSTOMER',[
#     [
#       "id", 377488,
#       "paymentStrategy", "ASSUMED_BY_GLOVO",
#       "addresses", [558026,560383,559448,558073],
#       "commissionOnDiscountedPrice", False,
#       "subsidyStrategy", "BY_PERCENTAGE",
# ...

# %%
import requests
import json
import time
import pandas as pd
import ast

# Base URL of the API endpoint
base_url = 'https://adminapi.glovoapp.com/admin/partner_promotions'

# Headers for the request
headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'es-ES,es;q=0.9,en;q=0.8',
    'authorization': 'eyJraWQiOiJvbGQiLCJhbGciOiJSUzUxMiJ9..GJdCxHZILyZK_l52chGsL7VOGjwlJOKPKOZqyee7umF4QuyGNS-M8YZmS2d_Kd_zyBJsmSc-qTETuiKa3nbzYG8NJHYuwNStPA5ee1shUmKHmHyFEoX2wCL2qGBrV72AAw85k9-6zPG2oU8vYWB51yU0J7aDy-2rVlBZ7na8wZ_XCQIZEvGG2DH_VsxWc8ehirLUApEjuhNWz2VzSE4GZZ4mVSK3nS7GFShcRmMekKJm_2s2c7eqWXcMIv_rW8tLU9r8ObsTG0AFciLFwo84cuUs7Re8_OIyKa5xghn6dOZqdwI-jkiEUbDd25_2NqY6ZnK_3SyJSQekn9JLvi_F4Q',
    'content-type': 'application/json',
    'glovo-api-version': '6',
    'glovo-app-platform': 'web',
    'glovo-app-type': 'admin',
    'glovo-app-version': '1.570.0',
    'glovo-client-info': 'web-admin/1.570.0 project:admin',
    'glovo-request-id': '22dcbe86-e27d-47af-a00b-d863df2a7802',
    'glovo-user-id': '56411963',
    'origin': 'https://beta-admin.glovoapp.com',
    'priority': 'u=1, i',
    'referer': 'https://beta-admin.glovoapp.com/'
}

def flatten(lst):
    flat_list = []
    for item in lst:
        if isinstance(item, list):
            flat_list.extend(flatten(item))
        else:
            flat_list.append(item)
    return flat_list

sheets_list = ast.literal_eval(concatenated_output)

total_promos = 0

error_log = pd.DataFrame(columns=["sheet_data", "status_code", "response_content"])

for sheet_list in sheets_list:
    total_promos += 1
    time.sleep(1)
    addresses = sheet_list[7][0][5]
    flattened_list = flatten(sheet_list)
    params_dict = {
        "type": flattened_list[0],
        "cityCode": flattened_list[1],
        "name": flattened_list[2],
        "startDate": 1743757200000,
        "endDate": flattened_list[4],
        "prime": False,
        "audience": "GLOVO_NEW_CUSTOMER",
        "partners": [
            {
                "id": flattened_list[8],
                "paymentStrategy": "ASSUMED_BY_GLOVO",
                "addresses": addresses,
                "commissionOnDiscountedPrice": False,
                "subsidyStrategy": "BY_PERCENTAGE",
                "sponsors": [
                    {
                        "sponsorId": 1,
                        "sponsorName": "Glovo",
                        "sponsorOrigin": "GLOVO",
                        "subsidyValue": 100,
                    }
                ],
            }
        ],
        "percentage": flattened_list[-5],
        "deliveryFeeCents": None,
        "minimumBasketSizeCents": flattened_list[-3],
        "openingTimes": None,
        "capCents": flattened_list[-1],
    }
    if params_dict["percentage"] == 100 or params_dict["capCents"] is None:
        print("BAD FORMATTING")

    response = requests.post(base_url, headers=headers, data=json.dumps(params_dict))
    print(response.status_code)
    print(response.json())

    if response.status_code != 200 and response.status_code != 409:
        # Log the error
        # Crea un DataFrame temporal con los datos que quieres agregar
        new_row = pd.DataFrame([{
            "sheet_data": sheet_list,
            "status_code": response.status_code,
            "response_content": response.json(),
        }])

        # Concatena el DataFrame existente con el nuevo
        error_log = pd.concat([error_log, new_row], ignore_index=True)
        print("Error logged")

# After the loop, you can save or analyze the error_log DataFrame
print(error_log)
# Out:
# 200
# ...

# %%
error_log.to_csv('error_log.csv', index=False)
error_log
# Out:
# Empty DataFrame
# Columns: [sheet_data, status_code, response_content]
# Index: []
